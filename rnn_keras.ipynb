# %% [markdown]
# # RNN・LSTM(Keras)

# %%
import numpy as np
import tensorflow
import matplotlib.pyplot as plt
% matplotlib inline
import seaborn as sns
sns.set()
# Out:
# C:\Users\Admin01\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ## データ生成

# %%
# sin曲線+ノイズ
ts = np.linspace(0, 10 * np.pi, 500)
ys = np.sin(ts) + np.random.normal(scale=0.1, size=len(ts))

# %%
plt.plot(ts, ys)

# %%
# 学習設定
batch_size = 32    # ミニバッチサイズ
n_steps = 50       # 入力系列の長さ
input_size = 1     # 入力の次元
hidden_size = 50   #  中間層の次元
output_size = 1    # 出力層の次元

lr = 0.005         # 学習率(SGD)
n_iter = 300       # イテレーション回数

# %%
# 訓練データとテストデータに分割
train_ratio = 0.8
data = []
for i in range(len(ys) - n_steps - 1):
    data.append(ys[i: i+n_steps+1])
data = np.array(data, dtype=np.float32)
n_train = int(train_ratio * len(data))
x_train, y_train = np.split(data[:n_train], [-1], axis=1)
x_test, y_test = np.split(data[n_train:], [-1], axis=1)

x_train = np.reshape(x_train, [-1, n_steps, input_size])
x_test = np.reshape(x_test, [-1, n_steps, input_size])

# %% [markdown]
# ## モデル構築

# %%
from keras.models import Sequential  
from keras.layers import SimpleRNN, LSTM, Dense
from keras.losses import mean_squared_error
from keras.optimizers import Adam, SGD

model = Sequential()  
model.add(SimpleRNN(hidden_size))
# model.add(LSTM(hidden_size))
model.add(Dense(output_size))

# 損失関数と最適化手法を設定
model.compile(loss=mean_squared_error,
                          optimizer=Adam()
#                           optimizer=SGD(lr)
                          )
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 学習

# %%
epochs = int(n_iter * batch_size / len(x_train))
model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs)
# Out:
# Epoch 1/26
# 359/359 [==============================] - 0s 644us/step - loss: 0.0997
# Epoch 2/26
# 359/359 [==============================] - 0s 146us/step - loss: 0.0250
# Epoch 3/26
# 359/359 [==============================] - 0s 151us/step - loss: 0.0179
# Epoch 4/26
# 359/359 [==============================] - 0s 163us/step - loss: 0.0159
# Epoch 5/26
# 359/359 [==============================] - 0s 164us/step - loss: 0.0134
# Epoch 6/26
# 359/359 [==============================] - 0s 159us/step - loss: 0.0126
# Epoch 7/26
# 359/359 [==============================] - 0s 159us/step - loss: 0.0118
# Epoch 8/26
# 359/359 [==============================] - 0s 166us/step - loss: 0.0112
# Epoch 9/26
# 359/359 [==============================] - 0s 174us/step - loss: 0.0114
# Epoch 10/26
# 359/359 [==============================] - 0s 173us/step - loss: 0.0111
# Epoch 11/26
# 359/359 [==============================] - 0s 173us/step - loss: 0.0110
# Epoch 12/26
# 359/359 [==============================] - 0s 185us/step - loss: 0.0109
# Epoch 13/26
# 359/359 [==============================] - 0s 189us/step - loss: 0.0107
# Epoch 14/26
# 359/359 [==============================] - 0s 162us/step - loss: 0.0112
# Epoch 15/26
# 359/359 [==============================] - 0s 159us/step - loss: 0.0108
# Epoch 16/26
# 359/359 [==============================] - 0s 175us/step - loss: 0.0109
# Epoch 17/26
# 359/359 [==============================] - 0s 174us/step - loss: 0.0119
# Epoch 18/26
# 359/359 [==============================] - 0s 153us/step - loss: 0.0111
# Epoch 19/26
# 359/359 [==============================] - 0s 180us/step - loss: 0.0110
# Epoch 20/26
# 359/359 [==============================] - 0s 159us/step - loss: 0.0107
# Epoch 21/26
# 359/359 [==============================] - 0s 170us/step - loss: 0.0110
# Epoch 22/26
# 359/359 [==============================] - 0s 167us/step - loss: 0.0101
# Epoch 23/26
# 359/359 [==============================] - 0s 173us/step - loss: 0.0104
# Epoch 24/26
# 359/359 [==============================] - 0s 196us/step - loss: 0.0104
# Epoch 25/26
# 359/359 [==============================] - 0s 200us/step - loss: 0.0105
# Epoch 26/26
# 359/359 [==============================] - 0s 180us/step - loss: 0.0107

# %% [markdown]
# ## テスト

# %%
# テストデータに対する予測
prediction = model.predict(x_test)

# 1次元配列に
prediction = prediction.reshape(-1)
true_y = y_test.reshape(-1)

# %%
# テストデータに対する予測を可視化
xx = np.arange(len(prediction))
plt.plot(xx, true_y, label='true')
plt.plot(xx, prediction, label='prediction')
plt.legend()

# %% [markdown]
# ## 再帰的な予測

# %%
# テストデータの最初のデータからスタートし、
# モデルの予測を利用し再帰的に予測
curr_x = x_test[0]
predicted = []
# 予測するステップ数
N = 200
for i in range(N):
    # 予測
    predicted.append(model.predict(curr_x[None]))
    # 入力を更新
    curr_x = np.insert(curr_x, n_steps, predicted[-1], axis=0)[1:]

# 1次元配列に
predicted = np.array(predicted).reshape(-1)

# %%
#再帰的な予測を可視化
plt.plot(xx, true_y, label='true')
plt.plot(np.arange(N), predicted, label='prediction')
plt.legend()
